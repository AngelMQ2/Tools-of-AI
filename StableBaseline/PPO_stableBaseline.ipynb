# %% [markdown]
# # Proximal Policy Optimizator
#
# The PPO is a RL algorithm that combine ideas from A2C (Actor-Critic) and TRPO (Trust Region Policy Optimization) in such way that learn using exploration-exploitation throught several iteration (A2C) but constraining the policy update step to be closer to the previous policy, thus, using a trust region to improve the actor.

# %%
import os
from datetime import datetime
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
#from stable_baselines3.common.vec_env import VecNormalize, DummyVecEnv, SubprocVecEnv, VecFrameStack, VecTransposeImageç

# %% [markdown]
# ## Create and Training model

# %%
# Set path to logfile and model file:
root = './PPO/'

log_path = os.path.join(root, 'LogFiles/')
log_name = datetime.now().strftime('%Y-%m-%d_%H-%M')
model_path = os.path.join(root, f"Models/model_{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.zip")

print(log_path+log_name)
print(model_path)
# Out:
# ./PPO/LogFiles/2024-05-05_22-10
# ./PPO/Models/model_2024-05-05_22-10-39.zip

# %%
# Create multiples environments in parallel:
vec_env = make_vec_env("Humanoid-v4", n_envs=10)


#vec_env = VecNormalize(VecFrameStack(VecTransposeImage(vec_env, transpose=True))) # Normalize and stack multiples observations and rewards
#vec_env.training_env.logger = gym.logger                                          # Set training logger
#vec_env = VecNormalize.load(log_path, vec_env)                                    # Load previous stasts - in case that interrupted training#      

# Initialize PPO model:
model = PPO("MlpPolicy", 
            vec_env, 
            device='cuda',
            verbose=1, 
            tensorboard_log = log_path,

            # Tunning params:
            learning_rate = 3e-4,
            n_steps = 2048,                 # Number of step for agent live
            n_epochs = 4,                   # Optimize/Learning steps
            batch_size =64,                # Number of samples (action, reward) used for optimize cycle
            gamma = 0.9,                   # Decay factor, influence of future reward against current
            ent_coef = 0.01,                # Entropy: determin randomization in pdf of action to take (low value = deterministic, high value = stocastic)
            vf_coef = 0.5,                    # Relative importance of value function in training
            use_sde = False,                # SDE = State Dependent Exploration, include stochastic noice
            sde_sample_freq = -1,           # Frequency of sample a noise matrix (-1 = only sample at the begining of the rollout)
            normalize_advantage = True      # Normalize value function
)

# Training loop:
model.learn(total_timesteps=1e7, tb_log_name=log_name)
#model.learn(total_timesteps=1e7, tb_log_name="2024-05-02_22-12",reset_num_timesteps=False )
# Save model
model.save(model_path)

del model # remove to demonstrate saving and loading
# Out:
# Using cuda device
# Logging to ./PPO/LogFiles/2024-05-05_22-10_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    fps             | 1883     |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 20480    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.2        |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 1496        |
# |    iterations           | 2           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016075846 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.2       |
# |    explained_variance   | 0.00293     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.2        |
# |    n_updates            | 4           |
# |    policy_gradient_loss | -0.00589    |
# |    std                  | 1.01        |
# |    value_loss           | 185         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 1412        |
# |    iterations           | 3           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008618066 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0.0743      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 1.01        |
# |    value_loss           | 80.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.4       |
# |    ep_rew_mean          | 124        |
# | time/                   |            |
# |    fps                  | 1380       |
# |    iterations           | 4          |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00905701 |
# |    clip_fraction        | 0.0738     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -24.3      |
# |    explained_variance   | 0.524      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.8       |
# |    n_updates            | 12         |
# |    policy_gradient_loss | -0.0143    |
# |    std                  | 1.01       |
# |    value_loss           | 45.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.6        |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 1367        |
# |    iterations           | 5           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011867372 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.4       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 1.01        |
# |    value_loss           | 38          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 147         |
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 6           |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.014331621 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.4       |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 1.02        |
# |    value_loss           | 37.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.6        |
# |    ep_rew_mean          | 160         |
# | time/                   |             |
# |    fps                  | 1345        |
# |    iterations           | 7           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.016053135 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.4       |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15          |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 1.02        |
# |    value_loss           | 36          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.3        |
# |    ep_rew_mean          | 197         |
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 8           |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.018867284 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.4       |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.3        |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 1.02        |
# |    value_loss           | 36.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.4        |
# |    ep_rew_mean          | 190         |
# | time/                   |             |
# |    fps                  | 1328        |
# |    iterations           | 9           |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.017379947 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.5       |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 1.02        |
# |    value_loss           | 35.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.7       |
# |    ep_rew_mean          | 217        |
# | time/                   |            |
# |    fps                  | 1322       |
# |    iterations           | 10         |
# |    time_elapsed         | 154        |
# |    total_timesteps      | 204800     |
# | train/                  |            |
# |    approx_kl            | 0.01999807 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -24.5      |
# |    explained_variance   | 0.69       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10         |
# |    n_updates            | 36         |
# |    policy_gradient_loss | -0.0151    |
# |    std                  | 1.02       |
# |    value_loss           | 35.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.2        |
# |    ep_rew_mean          | 225         |
# | time/                   |             |
# |    fps                  | 1314        |
# |    iterations           | 11          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 225280      |
# | train/                  |             |
# |    approx_kl            | 0.020998094 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.5       |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 1.03        |
# |    value_loss           | 33.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.1        |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 1309        |
# |    iterations           | 12          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.020333638 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.6       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 1.03        |
# |    value_loss           | 30.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.2       |
# |    ep_rew_mean          | 289        |
# | time/                   |            |
# |    fps                  | 1307       |
# |    iterations           | 13         |
# |    time_elapsed         | 203        |
# |    total_timesteps      | 266240     |
# | train/                  |            |
# |    approx_kl            | 0.02191161 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -24.7      |
# |    explained_variance   | 0.726      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14         |
# |    n_updates            | 48         |
# |    policy_gradient_loss | -0.0124    |
# |    std                  | 1.03       |
# |    value_loss           | 29         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.1        |
# |    ep_rew_mean          | 293         |
# | time/                   |             |
# |    fps                  | 1305        |
# |    iterations           | 14          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.021955585 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.8       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 52          |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 1.04        |
# |    value_loss           | 24.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.6        |
# |    ep_rew_mean          | 289         |
# | time/                   |             |
# |    fps                  | 1301        |
# |    iterations           | 15          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 307200      |
# | train/                  |             |
# |    approx_kl            | 0.021856401 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.8       |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 1.05        |
# |    value_loss           | 24.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.7        |
# |    ep_rew_mean          | 306         |
# | time/                   |             |
# |    fps                  | 1296        |
# |    iterations           | 16          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.024669688 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.9       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00785    |
# |    std                  | 1.05        |
# |    value_loss           | 22.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.1        |
# |    ep_rew_mean          | 291         |
# | time/                   |             |
# |    fps                  | 1288        |
# |    iterations           | 17          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 348160      |
# | train/                  |             |
# |    approx_kl            | 0.021566471 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.9       |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.00984    |
# |    std                  | 1.05        |
# |    value_loss           | 21.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.4        |
# |    ep_rew_mean          | 319         |
# | time/                   |             |
# |    fps                  | 1281        |
# |    iterations           | 18          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.024372514 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25         |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.02        |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00811    |
# |    std                  | 1.06        |
# |    value_loss           | 19.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.9        |
# |    ep_rew_mean          | 314         |
# | time/                   |             |
# |    fps                  | 1275        |
# |    iterations           | 19          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.024664935 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25         |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.00894    |
# |    std                  | 1.06        |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.3        |
# |    ep_rew_mean          | 322         |
# | time/                   |             |
# |    fps                  | 1270        |
# |    iterations           | 20          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.027621454 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.1       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.19        |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00545    |
# |    std                  | 1.06        |
# |    value_loss           | 16.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.1        |
# |    ep_rew_mean          | 330         |
# | time/                   |             |
# |    fps                  | 1268        |
# |    iterations           | 21          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 430080      |
# | train/                  |             |
# |    approx_kl            | 0.025958175 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.2       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.04        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00618    |
# |    std                  | 1.06        |
# |    value_loss           | 15.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.6        |
# |    ep_rew_mean          | 344         |
# | time/                   |             |
# |    fps                  | 1266        |
# |    iterations           | 22          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.024318915 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.2       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.12        |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00588    |
# |    std                  | 1.07        |
# |    value_loss           | 15.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.5        |
# |    ep_rew_mean          | 331         |
# | time/                   |             |
# |    fps                  | 1264        |
# |    iterations           | 23          |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.026240464 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.3       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.31        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.00572    |
# |    std                  | 1.07        |
# |    value_loss           | 15.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 66.6       |
# |    ep_rew_mean          | 340        |
# | time/                   |            |
# |    fps                  | 1262       |
# |    iterations           | 24         |
# |    time_elapsed         | 389        |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.02831971 |
# |    clip_fraction        | 0.27       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -25.4      |
# |    explained_variance   | 0.85       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.27       |
# |    n_updates            | 92         |
# |    policy_gradient_loss | -0.00675   |
# |    std                  | 1.08       |
# |    value_loss           | 14         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66.5        |
# |    ep_rew_mean          | 342         |
# | time/                   |             |
# |    fps                  | 1261        |
# |    iterations           | 25          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 512000      |
# | train/                  |             |
# |    approx_kl            | 0.027637277 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.5       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.88        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00603    |
# |    std                  | 1.09        |
# |    value_loss           | 13.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.7        |
# |    ep_rew_mean          | 367         |
# | time/                   |             |
# |    fps                  | 1260        |
# |    iterations           | 26          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 532480      |
# | train/                  |             |
# |    approx_kl            | 0.028089974 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.6       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.94        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00536    |
# |    std                  | 1.09        |
# |    value_loss           | 13          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 70.4       |
# |    ep_rew_mean          | 361        |
# | time/                   |            |
# |    fps                  | 1258       |
# |    iterations           | 27         |
# |    time_elapsed         | 439        |
# |    total_timesteps      | 552960     |
# | train/                  |            |
# |    approx_kl            | 0.02853297 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -25.6      |
# |    explained_variance   | 0.848      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.14       |
# |    n_updates            | 104        |
# |    policy_gradient_loss | -0.00668   |
# |    std                  | 1.1        |
# |    value_loss           | 15.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.1        |
# |    ep_rew_mean          | 356         |
# | time/                   |             |
# |    fps                  | 1257        |
# |    iterations           | 28          |
# |    time_elapsed         | 455         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.026761686 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.7       |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.04        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00624    |
# |    std                  | 1.1         |
# |    value_loss           | 12.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.3        |
# |    ep_rew_mean          | 350         |
# | time/                   |             |
# |    fps                  | 1227        |
# |    iterations           | 29          |
# |    time_elapsed         | 483         |
# |    total_timesteps      | 593920      |
# | train/                  |             |
# |    approx_kl            | 0.027532864 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.8       |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.08        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.00682    |
# |    std                  | 1.11        |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68          |
# |    ep_rew_mean          | 346         |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 30          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 614400      |
# | train/                  |             |
# |    approx_kl            | 0.030871604 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.9       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.46        |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.00526    |
# |    std                  | 1.11        |
# |    value_loss           | 11.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.7        |
# |    ep_rew_mean          | 340         |
# | time/                   |             |
# |    fps                  | 1112        |
# |    iterations           | 31          |
# |    time_elapsed         | 570         |
# |    total_timesteps      | 634880      |
# | train/                  |             |
# |    approx_kl            | 0.028103799 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.9       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.41        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00645    |
# |    std                  | 1.12        |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.2        |
# |    ep_rew_mean          | 366         |
# | time/                   |             |
# |    fps                  | 1068        |
# |    iterations           | 32          |
# |    time_elapsed         | 613         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.028751064 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -26         |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.09        |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.00655    |
# |    std                  | 1.12        |
# |    value_loss           | 11.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 66.6       |
# |    ep_rew_mean          | 343        |
# | time/                   |            |
# |    fps                  | 1044       |
# |    iterations           | 33         |
# |    time_elapsed         | 647        |
# |    total_timesteps      | 675840     |
# | train/                  |            |
# |    approx_kl            | 0.02895154 |
# |    clip_fraction        | 0.275      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.1      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.09       |
# |    n_updates            | 128        |
# |    policy_gradient_loss | -0.00648   |
# |    std                  | 1.13       |
# |    value_loss           | 12.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.4        |
# |    ep_rew_mean          | 356         |
# | time/                   |             |
# |    fps                  | 1049        |
# |    iterations           | 34          |
# |    time_elapsed         | 663         |
# |    total_timesteps      | 696320      |
# | train/                  |             |
# |    approx_kl            | 0.032497827 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -26.2       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 132         |
# |    policy_gradient_loss | -0.00388    |
# |    std                  | 1.13        |
# |    value_loss           | 12.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 68.7       |
# |    ep_rew_mean          | 353        |
# | time/                   |            |
# |    fps                  | 1054       |
# |    iterations           | 35         |
# |    time_elapsed         | 679        |
# |    total_timesteps      | 716800     |
# | train/                  |            |
# |    approx_kl            | 0.03010711 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.2      |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.62       |
# |    n_updates            | 136        |
# |    policy_gradient_loss | -0.00314   |
# |    std                  | 1.14       |
# |    value_loss           | 12.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 66.7       |
# |    ep_rew_mean          | 344        |
# | time/                   |            |
# |    fps                  | 1059       |
# |    iterations           | 36         |
# |    time_elapsed         | 695        |
# |    total_timesteps      | 737280     |
# | train/                  |            |
# |    approx_kl            | 0.02934279 |
# |    clip_fraction        | 0.282      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.3      |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.94       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00616   |
# |    std                  | 1.14       |
# |    value_loss           | 12.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.8        |
# |    ep_rew_mean          | 360         |
# | time/                   |             |
# |    fps                  | 1063        |
# |    iterations           | 37          |
# |    time_elapsed         | 712         |
# |    total_timesteps      | 757760      |
# | train/                  |             |
# |    approx_kl            | 0.035635434 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -26.4       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6         |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00363    |
# |    std                  | 1.15        |
# |    value_loss           | 10.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.4        |
# |    ep_rew_mean          | 350         |
# | time/                   |             |
# |    fps                  | 1068        |
# |    iterations           | 38          |
# |    time_elapsed         | 728         |
# |    total_timesteps      | 778240      |
# | train/                  |             |
# |    approx_kl            | 0.027812798 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -26.5       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.81        |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.00569    |
# |    std                  | 1.15        |
# |    value_loss           | 11.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66.6        |
# |    ep_rew_mean          | 343         |
# | time/                   |             |
# |    fps                  | 1072        |
# |    iterations           | 39          |
# |    time_elapsed         | 744         |
# |    total_timesteps      | 798720      |
# | train/                  |             |
# |    approx_kl            | 0.033179574 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -26.6       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.00412    |
# |    std                  | 1.16        |
# |    value_loss           | 11          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 65.6       |
# |    ep_rew_mean          | 337        |
# | time/                   |            |
# |    fps                  | 1075       |
# |    iterations           | 40         |
# |    time_elapsed         | 761        |
# |    total_timesteps      | 819200     |
# | train/                  |            |
# |    approx_kl            | 0.03189858 |
# |    clip_fraction        | 0.301      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.7      |
# |    explained_variance   | 0.887      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.45       |
# |    n_updates            | 156        |
# |    policy_gradient_loss | -0.00435   |
# |    std                  | 1.17       |
# |    value_loss           | 11.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.4        |
# |    ep_rew_mean          | 354         |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 41          |
# |    time_elapsed         | 778         |
# |    total_timesteps      | 839680      |
# | train/                  |             |
# |    approx_kl            | 0.035087895 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -26.8       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.71        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00557    |
# |    std                  | 1.17        |
# |    value_loss           | 10.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 67.9       |
# |    ep_rew_mean          | 349        |
# | time/                   |            |
# |    fps                  | 1081       |
# |    iterations           | 42         |
# |    time_elapsed         | 795        |
# |    total_timesteps      | 860160     |
# | train/                  |            |
# |    approx_kl            | 0.03408873 |
# |    clip_fraction        | 0.3        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -26.9      |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.78       |
# |    n_updates            | 164        |
# |    policy_gradient_loss | -0.00531   |
# |    std                  | 1.18       |
# |    value_loss           | 10.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.8        |
# |    ep_rew_mean          | 363         |
# | time/                   |             |
# |    fps                  | 1084        |
# |    iterations           | 43          |
# |    time_elapsed         | 811         |
# |    total_timesteps      | 880640      |
# | train/                  |             |
# |    approx_kl            | 0.031640697 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27         |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.72        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.00583    |
# |    std                  | 1.18        |
# |    value_loss           | 11.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.8        |
# |    ep_rew_mean          | 366         |
# | time/                   |             |
# |    fps                  | 1087        |
# |    iterations           | 44          |
# |    time_elapsed         | 828         |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.035081524 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27         |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.9         |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.00376    |
# |    std                  | 1.19        |
# |    value_loss           | 10.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 70.9       |
# |    ep_rew_mean          | 364        |
# | time/                   |            |
# |    fps                  | 1090       |
# |    iterations           | 45         |
# |    time_elapsed         | 844        |
# |    total_timesteps      | 921600     |
# | train/                  |            |
# |    approx_kl            | 0.03362351 |
# |    clip_fraction        | 0.297      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.1      |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.56       |
# |    n_updates            | 176        |
# |    policy_gradient_loss | -0.00505   |
# |    std                  | 1.19       |
# |    value_loss           | 10.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72.9        |
# |    ep_rew_mean          | 375         |
# | time/                   |             |
# |    fps                  | 1094        |
# |    iterations           | 46          |
# |    time_elapsed         | 860         |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.033232756 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.1       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.42        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00512    |
# |    std                  | 1.2         |
# |    value_loss           | 11.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.9        |
# |    ep_rew_mean          | 348         |
# | time/                   |             |
# |    fps                  | 1097        |
# |    iterations           | 47          |
# |    time_elapsed         | 876         |
# |    total_timesteps      | 962560      |
# | train/                  |             |
# |    approx_kl            | 0.031546358 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.2       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.07        |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.0052     |
# |    std                  | 1.2         |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.2        |
# |    ep_rew_mean          | 347         |
# | time/                   |             |
# |    fps                  | 1101        |
# |    iterations           | 48          |
# |    time_elapsed         | 892         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.031981178 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.3       |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.19        |
# |    n_updates            | 188         |
# |    policy_gradient_loss | -0.00573    |
# |    std                  | 1.21        |
# |    value_loss           | 12.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 71.8       |
# |    ep_rew_mean          | 368        |
# | time/                   |            |
# |    fps                  | 1104       |
# |    iterations           | 49         |
# |    time_elapsed         | 908        |
# |    total_timesteps      | 1003520    |
# | train/                  |            |
# |    approx_kl            | 0.03669357 |
# |    clip_fraction        | 0.326      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.4      |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.14       |
# |    n_updates            | 192        |
# |    policy_gradient_loss | -0.00479   |
# |    std                  | 1.22       |
# |    value_loss           | 10.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 72.9       |
# |    ep_rew_mean          | 376        |
# | time/                   |            |
# |    fps                  | 1107       |
# |    iterations           | 50         |
# |    time_elapsed         | 924        |
# |    total_timesteps      | 1024000    |
# | train/                  |            |
# |    approx_kl            | 0.03301435 |
# |    clip_fraction        | 0.298      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -27.4      |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.06       |
# |    n_updates            | 196        |
# |    policy_gradient_loss | -0.00457   |
# |    std                  | 1.22       |
# |    value_loss           | 10.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.5        |
# |    ep_rew_mean          | 370         |
# | time/                   |             |
# |    fps                  | 1111        |
# |    iterations           | 51          |
# |    time_elapsed         | 940         |
# |    total_timesteps      | 1044480     |
# | train/                  |             |
# |    approx_kl            | 0.034374677 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.5       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.41        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00179    |
# |    std                  | 1.22        |
# |    value_loss           | 10.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.5        |
# |    ep_rew_mean          | 372         |
# | time/                   |             |
# |    fps                  | 1114        |
# |    iterations           | 52          |
# |    time_elapsed         | 955         |
# |    total_timesteps      | 1064960     |
# | train/                  |             |
# |    approx_kl            | 0.030772131 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.5       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.27        |
# |    n_updates            | 204         |
# |    policy_gradient_loss | -0.00608    |
# |    std                  | 1.23        |
# |    value_loss           | 11.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.2        |
# |    ep_rew_mean          | 368         |
# | time/                   |             |
# |    fps                  | 1116        |
# |    iterations           | 53          |
# |    time_elapsed         | 971         |
# |    total_timesteps      | 1085440     |
# | train/                  |             |
# |    approx_kl            | 0.034854077 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.6       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.14        |
# |    n_updates            | 208         |
# ...
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.7       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.41        |
# |    n_updates            | 1884        |
# |    policy_gradient_loss | -0.000915   |
# |    std                  | 12          |
# |    value_loss           | 12.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.1        |
# |    ep_rew_mean          | 386         |
# | time/                   |             |
# |    fps                  | 975         |
# |    iterations           | 473         |
# |    time_elapsed         | 9931        |
# |    total_timesteps      | 9687040     |
# | train/                  |             |
# |    approx_kl            | 0.033383615 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.8       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.8         |
# |    n_updates            | 1888        |
# |    policy_gradient_loss | -0.000111   |
# |    std                  | 12.1        |
# |    value_loss           | 12.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.2        |
# |    ep_rew_mean          | 387         |
# | time/                   |             |
# |    fps                  | 975         |
# |    iterations           | 474         |
# |    time_elapsed         | 9950        |
# |    total_timesteps      | 9707520     |
# | train/                  |             |
# |    approx_kl            | 0.029005364 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64         |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.46        |
# |    n_updates            | 1892        |
# |    policy_gradient_loss | -0.00127    |
# |    std                  | 12.2        |
# |    value_loss           | 13.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.3        |
# |    ep_rew_mean          | 405         |
# | time/                   |             |
# |    fps                  | 975         |
# |    iterations           | 475         |
# |    time_elapsed         | 9969        |
# |    total_timesteps      | 9728000     |
# | train/                  |             |
# |    approx_kl            | 0.025740009 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.1       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.78        |
# |    n_updates            | 1896        |
# |    policy_gradient_loss | -0.00396    |
# |    std                  | 12.3        |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.1        |
# |    ep_rew_mean          | 385         |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 476         |
# |    time_elapsed         | 9987        |
# |    total_timesteps      | 9748480     |
# | train/                  |             |
# |    approx_kl            | 0.027758334 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.2       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.14        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.00377    |
# |    std                  | 12.4        |
# |    value_loss           | 13.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.3        |
# |    ep_rew_mean          | 381         |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 477         |
# |    time_elapsed         | 10005       |
# |    total_timesteps      | 9768960     |
# | train/                  |             |
# |    approx_kl            | 0.030977318 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.3       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.38        |
# |    n_updates            | 1904        |
# |    policy_gradient_loss | -0.00195    |
# |    std                  | 12.4        |
# |    value_loss           | 11.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.3        |
# |    ep_rew_mean          | 402         |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 478         |
# |    time_elapsed         | 10024       |
# |    total_timesteps      | 9789440     |
# | train/                  |             |
# |    approx_kl            | 0.025809746 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.3       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.92        |
# |    n_updates            | 1908        |
# |    policy_gradient_loss | -0.00312    |
# |    std                  | 12.5        |
# |    value_loss           | 13.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 71         |
# |    ep_rew_mean          | 386        |
# | time/                   |            |
# |    fps                  | 976        |
# |    iterations           | 479        |
# |    time_elapsed         | 10041      |
# |    total_timesteps      | 9809920    |
# | train/                  |            |
# |    approx_kl            | 0.03271546 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -64.4      |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.7       |
# |    n_updates            | 1912       |
# |    policy_gradient_loss | -0.00205   |
# |    std                  | 12.6       |
# |    value_loss           | 12.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.8        |
# |    ep_rew_mean          | 428         |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 480         |
# |    time_elapsed         | 10065       |
# |    total_timesteps      | 9830400     |
# | train/                  |             |
# |    approx_kl            | 0.026073933 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.5       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.26        |
# |    n_updates            | 1916        |
# |    policy_gradient_loss | -0.0027     |
# |    std                  | 12.6        |
# |    value_loss           | 13.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 76.1       |
# |    ep_rew_mean          | 416        |
# | time/                   |            |
# |    fps                  | 976        |
# |    iterations           | 481        |
# |    time_elapsed         | 10090      |
# |    total_timesteps      | 9850880    |
# | train/                  |            |
# |    approx_kl            | 0.03127142 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -64.5      |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.41       |
# |    n_updates            | 1920       |
# |    policy_gradient_loss | -0.000483  |
# |    std                  | 12.7       |
# |    value_loss           | 12         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.6        |
# |    ep_rew_mean          | 391         |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 482         |
# |    time_elapsed         | 10107       |
# |    total_timesteps      | 9871360     |
# | train/                  |             |
# |    approx_kl            | 0.033033807 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.6       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.58        |
# |    n_updates            | 1924        |
# |    policy_gradient_loss | -0.00257    |
# |    std                  | 12.8        |
# |    value_loss           | 11.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.6        |
# |    ep_rew_mean          | 421         |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 483         |
# |    time_elapsed         | 10128       |
# |    total_timesteps      | 9891840     |
# | train/                  |             |
# |    approx_kl            | 0.028770607 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.7       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.17        |
# |    n_updates            | 1928        |
# |    policy_gradient_loss | -0.00337    |
# |    std                  | 12.8        |
# |    value_loss           | 12          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 76.6       |
# |    ep_rew_mean          | 416        |
# | time/                   |            |
# |    fps                  | 977        |
# |    iterations           | 484        |
# |    time_elapsed         | 10144      |
# |    total_timesteps      | 9912320    |
# | train/                  |            |
# |    approx_kl            | 0.02954711 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -64.8      |
# |    explained_variance   | 0.894      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.56       |
# |    n_updates            | 1932       |
# |    policy_gradient_loss | -0.00367   |
# |    std                  | 12.9       |
# |    value_loss           | 13         |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 76         |
# |    ep_rew_mean          | 417        |
# | time/                   |            |
# |    fps                  | 977        |
# |    iterations           | 485        |
# |    time_elapsed         | 10161      |
# |    total_timesteps      | 9932800    |
# | train/                  |            |
# |    approx_kl            | 0.02766661 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -64.9      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4          |
# |    n_updates            | 1936       |
# |    policy_gradient_loss | -0.00202   |
# |    std                  | 13         |
# |    value_loss           | 12.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.4        |
# |    ep_rew_mean          | 400         |
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 486         |
# |    time_elapsed         | 10178       |
# |    total_timesteps      | 9953280     |
# | train/                  |             |
# |    approx_kl            | 0.030523235 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65         |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.59        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.000183   |
# |    std                  | 13.1        |
# |    value_loss           | 11.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.4        |
# |    ep_rew_mean          | 415         |
# | time/                   |             |
# |    fps                  | 978         |
# |    iterations           | 487         |
# |    time_elapsed         | 10195       |
# |    total_timesteps      | 9973760     |
# | train/                  |             |
# |    approx_kl            | 0.030422235 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65         |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.23        |
# |    n_updates            | 1944        |
# |    policy_gradient_loss | -0.00249    |
# |    std                  | 13.1        |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 75.4      |
# |    ep_rew_mean          | 413       |
# | time/                   |           |
# |    fps                  | 978       |
# |    iterations           | 488       |
# |    time_elapsed         | 10212     |
# |    total_timesteps      | 9994240   |
# | train/                  |           |
# |    approx_kl            | 0.0275532 |
# |    clip_fraction        | 0.179     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -65.1     |
# |    explained_variance   | 0.874     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.6       |
# |    n_updates            | 1948      |
# |    policy_gradient_loss | -0.00179  |
# |    std                  | 13.2      |
# |    value_loss           | 14        |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.9        |
# |    ep_rew_mean          | 407         |
# | time/                   |             |
# |    fps                  | 979         |
# |    iterations           | 489         |
# |    time_elapsed         | 10228       |
# |    total_timesteps      | 10014720    |
# | train/                  |             |
# |    approx_kl            | 0.029874101 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.2       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.38        |
# |    n_updates            | 1952        |
# |    policy_gradient_loss | -0.00246    |
# |    std                  | 13.3        |
# |    value_loss           | 13.3        |
# -----------------------------------------

# %% [markdown]
# ## Test

# %%
test_path = model_path
model = PPO.load(test_path)

# Create environment
#env = gym.make("Humanoid-v4", terminate_when_unhealthy=True, forward_reward_weight= 1.75)
vec_env = make_vec_env("Humanoid-v4", n_envs=6)

obs = vec_env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 test_path = model_path
# ----> 2 model = PPO.load(test_path)
#       4 # Create environment
#       5 #env = gym.make("Humanoid-v4", terminate_when_unhealthy=True, forward_reward_weight= 1.75)
#       6 vec_env = make_vec_env("Humanoid-v4", n_envs=6)
#
# File c:\Users\angel\anaconda3\envs\gym\lib\site-packages\stable_baselines3\common\base_class.py:680, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     677     print("== CURRENT SYSTEM INFO ==")
#     678     get_system_info()
# --> 680 data, params, pytorch_variables = load_from_zip_file(
#     681     path,
#     682     device=device,
#     683     custom_objects=custom_objects,
#     684     print_system_info=print_system_info,
#     685 )
#     687 assert data is not None, "No data found in the saved file"
#     688 assert params is not None, "No params found in the saved file"
#
# File c:\Users\angel\anaconda3\envs\gym\lib\site-packages\stable_baselines3\common\save_util.py:403, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     376 def load_from_zip_file(
#     377     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     378     load_data: bool = True,
#    (...)
#     382     print_system_info: bool = False,
#     383 ) -> Tuple[Optional[Dict[str, Any]], TensorDict, Optional[TensorDict]]:
#     384     """
#     385     Load model data from a .zip archive
#     386
#    (...)
#     401         and dict of pytorch variables
#     402     """
# --> 403     file = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     405     # set device to cpu if cuda is not available
#     406     device = get_device(device=device)
#
# File c:\Users\angel\anaconda3\envs\gym\lib\functools.py:889, in singledispatch.<locals>.wrapper(*args, **kw)
#     885 if not args:
#     886     raise TypeError(f'{funcname} requires at least '
#     887                     '1 positional argument')
# --> 889 return dispatch(args[0].__class__)(*args, **kw)
#
# File c:\Users\angel\anaconda3\envs\gym\lib\site-packages\stable_baselines3\common\save_util.py:240, in open_path_str(path, mode, verbose, suffix)
#     225 @open_path.register(str)
#     226 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     227     """
#     228     Open a path given by a string. If writing to the path, the function ensures
#     229     that the path exists.
#    (...)
#     238     :return:
#     239     """
# --> 240     return open_path_pathlib(pathlib.Path(path), mode, verbose, suffix)
#
# File c:\Users\angel\anaconda3\envs\gym\lib\site-packages\stable_baselines3\common\save_util.py:291, in open_path_pathlib(path, mode, verbose, suffix)
#     285         path.parent.mkdir(exist_ok=True, parents=True)
#     287 # if opening was successful uses the open_path() function
#     288 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     289 #   with corrections
#     290 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 291 return open_path_pathlib(path, mode, verbose, suffix)
#
# File c:\Users\angel\anaconda3\envs\gym\lib\site-packages\stable_baselines3\common\save_util.py:272, in open_path_pathlib(path, mode, verbose, suffix)
#     270             path, suffix = newpath, None
#     271         else:
# --> 272             raise error
#     273 else:
#     274     try:
#
# File c:\Users\angel\anaconda3\envs\gym\lib\site-packages\stable_baselines3\common\save_util.py:264, in open_path_pathlib(path, mode, verbose, suffix)
#     262 if mode == "r":
#     263     try:
# --> 264         return open_path(path.open("rb"), mode, verbose, suffix)
#     265     except FileNotFoundError as error:
#     266         if suffix is not None and suffix != "":
#
# File c:\Users\angel\anaconda3\envs\gym\lib\pathlib.py:1119, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1117 if "b" not in mode:
#    1118     encoding = io.text_encoding(encoding)
# -> 1119 return self._accessor.open(self, mode, buffering, encoding, errors,
#    1120                            newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'PPO\\Models\\model_2024-05-05_01-08-04.zip.zip'
